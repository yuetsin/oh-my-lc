# %% [markdown]
# # 389
#
# 好遗憾地讲，这题根本就没把英语讲清楚。
#
# String t is generated by random shuffling string s and then add one more letter at a random position.
#
# 好的，shuffle s 我晓得，然后呢？
#
# add one more letter at a random position
#
# add 一个或多个 letter…
#
# a random position？
#
# 一个 random position 插多个？
#
# 这多个能不能一样？
#
# 给的例子也是不清不白：
# s = "abcd"
# t = "abcde"
#
# 我们来替他说两句人话：
#
# 它想表达的意思是：先 Shuffle，然后在随机的几个位置中插入同一个字母。
#
# 找出这个字母。
#
# …写代码写傻掉了
